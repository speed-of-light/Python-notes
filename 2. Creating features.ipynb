# %%
datapath = os.path.expanduser('~')+'/projects/ipranker/dataset'

# %%
traindata = pd.read_csv(datapath+'/training_pped.csv', index_col=0)

# %%
traindata.values
# Out:
# array([[ 1. ,  7.2,  2. ],
#        [ 1. ,  7.4,  2. ],
#        [ 1. ,  8. ,  1. ],
#        [ 1. ,  8. ,  1. ],
#        [ 1. ,  7.6,  2. ],
#        [ 1. ,  7.2,  2. ],
#        [ 1. ,  7.2,  2. ],
#        [ 1. ,  8. ,  1. ],
#        [ 1. ,  7.4,  2. ],
#        [ 2. ,  5.2,  3. ],
#        [ 1. ,  8.2,  1. ],
#        [ 2. ,  6.2,  2. ],
#        [ 1. ,  7.2,  2. ],
#        [ 2. ,  5.8,  2. ],
#        [ 2. ,  5.8,  2. ],
#        [ 2. ,  6.4,  2. ],
#        [ 2. ,  6.4,  2. ],
#        [ 2. ,  5.8,  2. ],
#        [ 1. ,  7.8,  2. ],
#        [ 2. ,  6. ,  2. ],
#        [ 2. ,  5.2,  3. ],
#        [ 2. ,  5.6,  2. ],
#        [ 2. ,  5.4,  2. ],
#        [ 2. ,  5.8,  2. ],
#        [ 2. ,  4.6,  3. ],
#        [ 1. ,  8. ,  1. ],
#        [ 1. ,  8.8,  1. ],
#        [ 2. ,  7. ,  2. ],
#        [ 1. ,  7.8,  2. ],
#        [ 2. ,  7. ,  2. ],
#        [ 1. ,  7.4,  2. ],
#        [ 2. ,  4.6,  3. ],
#        [ 1. ,  7.2,  2. ],
#        [ 2. ,  5.8,  2. ],
# ...

# %%
hue = scv.HueHistogramFeatureExtractor(mNBins=16)

# %%
tImgs = ImageSet(datapath + "/training")
#tImgs.load(tp, 'jpg')

# %%
img = scv.Image(datapath + '/training/001.jpg')
img.show()
# Out:
# <SimpleCV.Display Object resolution:((2048, 1536)), Image Resolution: (2048, 1536) at memory location: (0x110430c68)>

# %%
plot(arange(10))
