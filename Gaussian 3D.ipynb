# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.gca(projection='3d')
ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

X, Y, Z = axes3d.get_test_data(0.03)
ax.plot_surface(X, Y, Z, rstride=10, cstride=10, alpha=0.3)
cset = ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)
plt.show()

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.gca(projection='3d')
ax.set_xlabel('X')
ax.set_xlim(-4, 4)
ax.set_ylabel('Y')
ax.set_ylim(4, -4)
ax.set_zlabel('Z')
ax.set_zlim(-1, 1)

delta = 0.05
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-3.0, 3.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = mlab.bivariate_normal(X, Y, 1, 1, 0.0, 0.0)
Z2 = mlab.bivariate_normal(X, Y, 1.0, 1.5, 0.0, 0.0)
levels = arange(-4.0, 4.0, 0.1)
# difference of Gaussians
Z = 10.0 * (Z2 - Z1)

cset = ax.contourf(X, Y, Z, zdir='z', offset=-1, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=-4, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-4, cmap=cm.coolwarm)
ax.plot_surface(X, Y, Z, rstride=5, cstride=5, alpha=0.3)
plt.show()
